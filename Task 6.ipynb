# %%
import numpy as np
import matplotlib.pyplot as plt


# Parameters
S0 = 35
K = 35
T = 1
r = 0.03
q = 0.04
sigma = 0.45

S_max = 3 * S0  # Stock price upper bound
M = 1000         # Number of stock price steps
N = 1000         # Number of time steps


# Discretisation
dS = S_max / M  # Stock price increment
dt = T / N      # Time increment


# Grid initialisation
stock_prices = np.linspace(0, S_max, M + 1)
option_values = np.zeros((M + 1, N + 1))        # 2D array for option values


# Boundary conditions at maturity
# American put payoff at maturity = max(K - S, 0)
option_values[:, -1] = np.maximum(K - stock_prices, 0)


# Coefficient initialisation
j = np.arange(1, M)     # Index for internal nodes


# Coefficients for implicit method
alpha = 0.5 * dt * ((r - q) * j - (sigma**2) * j**2)
beta = 1 + dt * (sigma**2 * j**2 + (r - q)) 
gamma = -0.5 * dt * ((r - q) * j + (sigma**2) * j**2)


# Prepare vectors for the tridiagonal matrix
a = np.zeros(M - 1)     # Lower diagonal (alpha)
b = np.zeros(M - 1)     # Main diagonal (beta)
c = np.zeros(M - 1)     # Upper diagonal (gamma)
d = np.zeros(M - 1)     # Right-hand side vector (option_values)


# Backward induction using the implicit method
for n in range(N-1, -1, -1):

    # Fill the coefficients a, b, c, & d
    for i in range(1, M):
        a[i - 1] = alpha[i - 1]
        b[i - 1] = beta[i - 1]
        c[i - 1] = gamma[i - 1]
        d[i - 1] = option_values[i, n + 1]

    # Adjust the boundary conditions at each time step
    d[0] -= a[0] * K        # Adjust for lower boundary
    d[-1] -= c[-1] * 0      # Adjust for upper boundary
        
    # Solve the tridiagonal system using numpy's built-in solver
    option_values[1:M, n]  = np.linalg.solve(
        np.diag(b) + np.diag(a[1:], -1) + np.diag(c[:-1], 1), d)
    
    # Early exercise condition for American option
    option_values[1:M, n] = np.maximum(
        option_values[1:M, n], K - stock_prices[1:M])

    # Boundary conditions for stock price extremes
    option_values[0, n] = K     # When stock price is 0, option value is K
    option_values[M, n] = 0     # When stock price is very high, option value is 0


# Extract the option price for the initial stock price, S0
initial_price_index = np.searchsorted(stock_prices, S0)
american_put_price = option_values[initial_price_index, 0]
print(f"The American put option price at S0 = {S0} is approximately: {american_put_price:.4f}")


# Plotting teh option price as a function of stock price at the initial time t = 0
plt.figure(figsize=(10, 6))
plt.plot(stock_prices, option_values[:, 0], label='American Put Option Value at t=0')
plt.xlabel('Stock Price', fontsize=18)
plt.ylabel('Option Value', fontsize=18)
plt.title('Implicit Finite Difference', fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.grid(True, which = 'major', linestyle = '-')
plt.grid(True, which = 'minor', linestyle = '--')


plt.axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = 35$')
plt.axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = 6.410$')
plt.scatter(35, 6.410, color='black', zorder=5)
plt.text(36, 6.5, '($S_0$, $V(S_0)$)', fontsize=14, color='black')



plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Excel file
file_path = 'option_values.csv'  
data = pd.read_csv(file_path)

x = data.iloc[:, 0]  
y = data.iloc[:, 1]  

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='American Put Option Value at t=0')
plt.xlabel('Stock Price', fontsize=18)  
plt.ylabel('Option Value', fontsize=18) 
plt.title('Explicit Finite Difference', fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=18)

plt.axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = 35$')
plt.axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = 6.410$')
plt.scatter(35, 6.410, color='black', zorder=5)
plt.text(36, 6.5, '($S_0$, $V(S_0)$)', fontsize=14, color='black')

plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Parameters
S0 = 35
K = 35
T = 1
r = 0.03
q = 0.04
sigma = 0.45

S_max = 3 * S0  # Stock price upper bound
M = 1000         # Number of stock price steps
N = 1000         # Number of time steps

# Discretisation
dS = S_max / M  # Stock price increment
dt = T / N      # Time increment

# Grid initialisation
stock_prices = np.linspace(0, S_max, M + 1)
option_values = np.zeros((M + 1, N + 1))        # 2D array for option values

# Boundary conditions at maturity
# American put payoff at maturity = max(K - S, 0)
option_values[:, -1] = np.maximum(K - stock_prices, 0)

# Coefficient initialisation
j = np.arange(1, M)     # Index for internal nodes

# Coefficients for implicit method
alpha = 0.5 * dt * ((r - q) * j - (sigma**2) * j**2)
beta = 1 + dt * (sigma**2 * j**2 + (r - q)) 
gamma = -0.5 * dt * ((r - q) * j + (sigma**2) * j**2)

# Prepare vectors for the tridiagonal matrix
a = np.zeros(M - 1)     # Lower diagonal (alpha)
b = np.zeros(M - 1)     # Main diagonal (beta)
c = np.zeros(M - 1)     # Upper diagonal (gamma)
d = np.zeros(M - 1)     # Right-hand side vector (option_values)

# Backward induction using the implicit method
for n in range(N-1, -1, -1):
    # Fill the coefficients a, b, c, & d
    for i in range(1, M):
        a[i - 1] = alpha[i - 1]
        b[i - 1] = beta[i - 1]
        c[i - 1] = gamma[i - 1]
        d[i - 1] = option_values[i, n + 1]

    # Adjust the boundary conditions at each time step
    d[0] -= a[0] * K        # Adjust for lower boundary
    d[-1] -= c[-1] * 0      # Adjust for upper boundary
        
    # Solve the tridiagonal system using numpy's built-in solver
    option_values[1:M, n]  = np.linalg.solve(
        np.diag(b) + np.diag(a[1:], -1) + np.diag(c[:-1], 1), d)
    
    # Early exercise condition for American option
    option_values[1:M, n] = np.maximum(
        option_values[1:M, n], K - stock_prices[1:M])

    # Boundary conditions for stock price extremes
    option_values[0, n] = K     # When stock price is 0, option value is K
    option_values[M, n] = 0     # When stock price is very high, option value is 0

# Extract the option price for the initial stock price, S0
initial_price_index = np.searchsorted(stock_prices, S0)
american_put_price = option_values[initial_price_index, 0]
print(f"The American put option price at S0 = {S0} is approximately: {american_put_price:.4f}")

# Load Excel file for explicit finite difference data
file_path = 'option_values.csv'  
data = pd.read_csv(file_path)
x = data.iloc[:, 0]  
y = data.iloc[:, 1]  

# Plotting both methods with a shared y-axis
fig, ax = plt.subplots(1, 2, figsize=(18, 6), sharey=True)

# Implicit Finite Difference Plot
ax[0].plot(stock_prices, option_values[:, 0],label='Explicit Finite Difference Curve')
ax[0].set_xlabel('Stock Price', fontsize=14)
ax[0].set_ylabel('Option Value', fontsize=14)
ax[0].set_title('Implicit Finite Difference', fontsize=18)
ax[0].grid(True)
ax[0].axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = 35$')
ax[0].axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = 6.409$')
ax[0].scatter(35, 6.410, color='black', zorder=5)
#ax[0].text(36, 6.5, '($S_0$, $V(S_0)$)', fontsize=12, color='black')
ax[0].legend(fontsize=14)

# Explicit Finite Difference Plot
ax[1].plot(x, y, label='Explicit Finite Difference Curve')
ax[1].set_xlabel('Stock Price', fontsize=14)
ax[1].set_title('Explicit Finite Difference', fontsize=18)
ax[1].grid(True)
ax[1].axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = 35$')
ax[1].axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = 6.410$')
ax[1].scatter(35, 6.410, color='black', zorder=5)
#ax[1].text(36, 6.5, '($S_0$, $V(S_0)$)', fontsize=12, color='black')
ax[1].legend(fontsize=14)

# Adjust layout and show the plot
plt.tight_layout()
plt.savefig('task6.png', bbox_inches='tight', dpi = 1200)
plt.show()
# Out:
# The American put option price at S0 = 35 is approximately: 6.4093

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Parameters
S0 = 35
K = 35
T = 1
r = 0.03
q = 0.04
sigma = 0.45

S_max = 3 * S0  # Stock price upper bound
M = 1000         # Number of stock price steps
N = 1000         # Number of time steps

# Discretisation
dS = S_max / M  # Stock price increment
dt = T / N      # Time increment

# Grid initialisation
stock_prices = np.linspace(0, S_max, M + 1)
option_values = np.zeros((M + 1, N + 1))        # 2D array for option values

# Boundary conditions at maturity
# American put payoff at maturity = max(K - S, 0)
option_values[:, -1] = np.maximum(K - stock_prices, 0)

# Coefficient initialisation
j = np.arange(1, M)     # Index for internal nodes

# Coefficients for implicit method
alpha = 0.5 * dt * ((r - q) * j - (sigma**2) * j**2)
beta = 1 + dt * (sigma**2 * j**2 + (r - q)) 
gamma = -0.5 * dt * ((r - q) * j + (sigma**2) * j**2)

# Prepare vectors for the tridiagonal matrix
a = np.zeros(M - 1)     # Lower diagonal (alpha)
b = np.zeros(M - 1)     # Main diagonal (beta)
c = np.zeros(M - 1)     # Upper diagonal (gamma)
d = np.zeros(M - 1)     # Right-hand side vector (option_values)

# Backward induction using the implicit method
for n in range(N-1, -1, -1):
    # Fill the coefficients a, b, c, & d
    for i in range(1, M):
        a[i - 1] = alpha[i - 1]
        b[i - 1] = beta[i - 1]
        c[i - 1] = gamma[i - 1]
        d[i - 1] = option_values[i, n + 1]

    # Adjust the boundary conditions at each time step
    d[0] -= a[0] * K        # Adjust for lower boundary
    d[-1] -= c[-1] * 0      # Adjust for upper boundary
        
    # Solve the tridiagonal system using numpy's built-in solver
    option_values[1:M, n]  = np.linalg.solve(
        np.diag(b) + np.diag(a[1:], -1) + np.diag(c[:-1], 1), d)
    
    # Early exercise condition for American option
    option_values[1:M, n] = np.maximum(
        option_values[1:M, n], K - stock_prices[1:M])

    # Boundary conditions for stock price extremes
    option_values[0, n] = K     # When stock price is 0, option value is K
    option_values[M, n] = 0     # When stock price is very high, option value is 0

# Extract the option price for the initial stock price, S0
initial_price_index = np.searchsorted(stock_prices, S0)
american_put_price = option_values[initial_price_index, 0]
print(f"The American put option price at S0 = {S0} is approximately: {american_put_price:.4f}")

# Load Excel file for explicit finite difference data
file_path = 'option_values.csv'  
data = pd.read_csv(file_path)
x = data.iloc[:, 0]  
y = data.iloc[:, 1]  

# Plotting both methods with subplots (stacked vertically)
fig, ax = plt.subplots(2, 1, figsize=(10, 12))  # Two subplots, stacked vertically

# Implicit Finite Difference Plot
ax[0].plot(stock_prices, option_values[:, 0], label='Implicit Finite Difference')
ax[0].set_xlabel('Stock Price ($)', fontsize=14)
ax[0].set_ylabel('Option Value ($)', fontsize=14)
ax[0].set_title('Implicit Finite Difference Method', fontsize=18)
ax[0].grid(True)
ax[0].axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = \$35$')
ax[0].axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = \$6.409$')
ax[0].scatter(35, 6.410, color='black', zorder=5)
ax[0].legend(fontsize=12)

# Explicit Finite Difference Plot
ax[1].plot(x, y, label='Explicit Finite Difference')
ax[1].set_xlabel('Stock Price ($)', fontsize=14)
ax[1].set_ylabel('Option Value ($)', fontsize=14)
ax[1].set_title('Explicit Finite Difference Method', fontsize=18)
ax[1].grid(True)
ax[1].axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = \$35$')
ax[1].axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = \$6.410$')
ax[1].scatter(35, 6.410, color='black', zorder=5)
ax[1].legend(fontsize=12)

# Adjust layout and save the plot
plt.tight_layout()
plt.savefig('task6_updated.png', bbox_inches='tight', dpi=1200)
plt.show()
# Out:
# <>:88: SyntaxWarning: invalid escape sequence '\$'
# <>:89: SyntaxWarning: invalid escape sequence '\$'
# <>:99: SyntaxWarning: invalid escape sequence '\$'
# <>:100: SyntaxWarning: invalid escape sequence '\$'
# <>:88: SyntaxWarning: invalid escape sequence '\$'
# <>:89: SyntaxWarning: invalid escape sequence '\$'
# <>:99: SyntaxWarning: invalid escape sequence '\$'
# <>:100: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\kaiti\AppData\Local\Temp\ipykernel_11224\2948113017.py:88: SyntaxWarning: invalid escape sequence '\$'
#   ax[0].axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = \$35$')
# C:\Users\kaiti\AppData\Local\Temp\ipykernel_11224\2948113017.py:89: SyntaxWarning: invalid escape sequence '\$'
#   ax[0].axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = \$6.409$')
# C:\Users\kaiti\AppData\Local\Temp\ipykernel_11224\2948113017.py:99: SyntaxWarning: invalid escape sequence '\$'
#   ax[1].axvline(x=35, color='red', linestyle='--', linewidth=1, label='$S_0 = \$35$')
# C:\Users\kaiti\AppData\Local\Temp\ipykernel_11224\2948113017.py:100: SyntaxWarning: invalid escape sequence '\$'
#   ax[1].axhline(y=6.410, color='blue', linestyle='--', linewidth=1, label='$V(S_0) = \$6.410$')
# The American put option price at S0 = 35 is approximately: 6.4093
